# %%
# Importing Required Module for Data Preperation And Analysis
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading CSV File 
data = pd.read_csv('mushrooms.csv')
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
# Number of CLasses Counts
data['class'].value_counts()
# Out:
# class
# e    4208
# p    3916
# Name: count, dtype: int64

# %% [markdown]
# As result shown above we have Two class Mushroom, **Edible** which is denoted by **'e'**. **Poisonous** which is denoted by **'p'**.

# %% [markdown]
# Analysis With Odor of Mushroom
# 1. almond=a
# 2. anise=l
# 3. creosote=c
# 4. fishy=y
# 5. foul=f
# 6. musty=m
# 7. none=n
# 8. pungent=p
# 9. spicy=s

# %%
# Updating Labels for odor
odor_dict = {"a": "Almond", "l": "Anise", "c": "Creosote", "y": "Fishy", "f": "Foul", "m": "Musty", "n": "None", "p": "Pungent", "s": "Spicy"} 
data['odor'] = data['odor'].apply(lambda x:odor_dict[x])

# %%
# Getting all Poisonous Mushroom odor   
Poisonous_Odor = data[data['class']=='p']['odor'].value_counts()

# # Showing With Pie Chart Poisonous_Odor
ordor_pos = Poisonous_Odor.plot(kind='bar',figsize=(12,5),fontsize=12)
ordor_pos.set_title('Poisonous Mushroom with their Odor',fontsize=14)
ordor_pos.tick_params(labelrotation=0)

# %% [markdown]
# The Foul type ordor is more in Poisonous Mushroom count

# %%
# Getting all Edible Mushroom odor
Edible_Odor = data[data['class']=='e']['odor'].value_counts()

# # Showing with Pie Chart Edible_Odor
ordor_ed = Edible_Odor.plot(kind='bar',figsize=(12,5),fontsize=12)
ordor_ed.set_title('Edible Mushroom with their Odor',fontsize=14)
ordor_ed.tick_params(labelrotation=0)

# %% [markdown]
# There is no odor for Edible Mushroom count is more than others.

# %% [markdown]
# Analysis with bruises
# Another feature to consider when identifying mushrooms is whether they bruise or bleed a specific color.

# %%
# Bruises Mushrooms :  
# t: Bruises:True
# f: No Bruises: False

Poisonous_Bruises = data[data['class']== 'p']['bruises'].value_counts()
Edible_Bruises = data[data['class']== 'e']['bruises'].value_counts()

Bruises = pd.DataFrame([Poisonous_Bruises,Edible_Bruises],
                       index=['Poisonous','Edible'])
Bruises.plot(kind = 'barh',stacked = True,figsize=(14,5),fontsize=12)
plt.title("Bruises Mushrooms",fontsize=14)
plt.legend(labels=["f = False","t = True"],fontsize=12)
plt.show()

# %% [markdown]
# As Shown above stcaked barplot the ratio of brusies
# - In Edible: bruises is more
# - In Poisonous: No Bruises is more

# %% [markdown]
# Analysis on Habitat Feature:
# In Given Dataset there are 7 habitat Mushroom are Used:
# - grasses=g
# - leaves=l
# - meadows=m
# - paths=p
# - urban=u
# - waste=w
# - woods=d

# %%
# Updating name for habitat feature
habitate_dict = {"g": "Grasses","l": "Leaves","m": "Meadows", "p": "Paths", "u": "Urban", "w": "Waste", "d": "Woods"}
data['habitat'] = data['habitat'].apply(lambda x:habitate_dict[x])

# %%
# Analysing Habitat for Edible Mushroom:
Edible_habitate = data[data['class'] == 'e']['habitat'].value_counts()
habit_ed = Edible_habitate.plot(kind='bar',figsize=(12,5),fontsize=12)
habit_ed.set_title('Edible Mushroom with their Habitat',fontsize=14)
habit_ed.tick_params(labelrotation=0)

# %% [markdown]
# The habitat type count shows the Wood and Grasses type is more.

# %%
# Analysing Habitat for Poisonous Mushroom:
Poisonous_habitate = data[data['class'] == 'p']['habitat'].value_counts()
habit_pos = Poisonous_habitate.plot(kind='bar',figsize=(12,5))
habit_pos.set_title('Poisonous Mushroom with their Habitat',fontsize=14)
habit_pos.tick_params(labelrotation=0)
plt.show()

# %% [markdown]
# ## Data Preprocessing
# Given data is in character or string.To apply Machine Learning Algorithm we need to convert int integers

# %%
data.head(3)
# Out:
#   class cap-shape cap-surface cap-color bruises     odor gill-attachment  \
# 0     p         x           s         n       t  Pungent               f
# 1     e         x           s         y       t   Almond               f
# 2     e         b           s         w       t    Anise               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population  habitat
# 0           o         p                 k          s    Urban
# 1           o         p                 n          n  Grasses
# 2           o         p                 n          n  Meadows
#
# [3 rows x 23 columns]

# %%
# basic label encoding
from sklearn.preprocessing import LabelEncoder
#Encode target labels with value between 0 and n_classes-1.
df = data.copy()
label_encoder = LabelEncoder()
for column in df.columns:
    df[column] = label_encoder.fit_transform(df[column])
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     7                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     1                1
# 3      1          5            3          8        1     7                1
# 4      0          5            2          3        0     6                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        4
# 1            1          4                  3           2        0
# 2            1          4                  3           2        2
# 3            1          4                  2           3        4
# 4            1          0                  3           0        0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Classification of Mushrooom Using Different Machine Learning Model

# %%
# Seaparating the labels and Features
Label = df['class']
Features = df.drop(['class'],axis=1)

# %%
# Spltting Data in Training and Testing Data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(Features,Label,random_state = 125)

# %%
# Importing Models
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
# from sklearn.neural_network import MLPClassifier

# %%
# 5 classifiers: kNN, Logistic Regression, SVM, Naive Bayes, MLP
models = {
    'LogisticRegression': LogisticRegression(max_iter=1000, random_state=125),
    'GaussianNB': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'SVM': SVC(probability=True, random_state=125),  # probability=True needed for ROC AUC
    # 'MLP': MLPClassifier(max_iter=1000, random_state=125)
}

# %%
import numpy as np

param_grids = {
    'LogisticRegression': {
        'C': [0.01, 0.1, 10],
        'penalty': ['l2'],
        'solver': ['lbfgs'],
        'class_weight': [None, 'balanced']
    },
    'GaussianNB': {
        'var_smoothing': [1e-9, 1e-8, 1e-6]
    },
    'KNN': {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance'],
        'p': [1, 2]        # 1 = Manhattan, 2 = Euclidean
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['rbf', 'linear']
    },
    'MLP': {
        'hidden_layer_sizes': [(50,), (100,)],
        'activation': ['relu', 'tanh'],
        'alpha': [0.0001, 0.001]
    }
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, roc_auc_score, f1_score, accuracy_score

# %%
gridsearches = {}
variance_results = {metric: {} for metric in scoring.keys()}
best_scores = {metric: {} for metric in scoring.keys()}

# %%
for name, model in models.items():
    print(f"Running GridSearchCV for: {name}")
    gs = GridSearchCV(
        estimator=model,
        param_grid=param_grids[name],
        scoring=scoring,
        refit='roc_auc',   # model refit on best ROC AUC
        cv=5,
        n_jobs=-1,
        return_train_score=False
    )
    gs.fit(X_train, y_train)
    gridsearches[name] = gs
    
    # For each metric, compute variance of mean CV scores across all hyperparameter combos
    for metric in scoring.keys():
        scores = gs.cv_results_[f'mean_test_{metric}']
        variance_results[metric][name] = np.var(scores)
        best_scores[metric][name] = scores.max()

print("\nVariance of scores across hyperparameters:")
for metric in scoring.keys():
    print(f"\nMetric: {metric}")
    for name in models.keys():
        print(f"  {name}: variance = {variance_results[metric][name]:.6f}")
# Out:
# Running GridSearchCV for: LogisticRegression
# Running GridSearchCV for: GaussianNB
# Running GridSearchCV for: KNN
# Running GridSearchCV for: SVM
#
# Variance of scores across hyperparameters:
#
# Metric: roc_auc
#   LogisticRegression: variance = 0.000205
#   GaussianNB: variance = 0.000000
#   KNN: variance = 0.000000
#   SVM: variance = 0.000374
#
# Metric: f1
#   LogisticRegression: variance = 0.000642
#   GaussianNB: variance = 0.000000
#   KNN: variance = 0.000000
#   SVM: variance = 0.000376
#
# Metric: accuracy
#   LogisticRegression: variance = 0.000509
#   GaussianNB: variance = 0.000000
#   KNN: variance = 0.000000
#   SVM: variance = 0.000343

# %%
import matplotlib.pyplot as plt
import numpy as np

model_names = list(models.keys())
x = np.arange(len(model_names))
width = 0.25

roc_vars = [variance_results['roc_auc'][m] for m in model_names]
f1_vars = [variance_results['f1'][m] for m in model_names]
acc_vars = [variance_results['accuracy'][m] for m in model_names]

plt.figure(figsize=(10, 6))

plt.bar(x - width, roc_vars, width, label='ROC AUC variance')
plt.bar(x, f1_vars, width, label='F1 variance')
plt.bar(x + width, acc_vars, width, label='Accuracy variance')

plt.xticks(x, model_names, rotation=45)
plt.ylabel('Variance of CV score')
plt.title('Hyperparameter sensitivity across classifiers')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Conclusion – Hyperparameter Sensitivity Analysis**
#
# * Hyperparameter sensitivity was analyzed for **kNN, Logistic Regression, SVM, and Naive Bayes** using **ROC AUC, F1-score, and Accuracy**.
# * **Support Vector Machine (SVM)** showed the **highest variance across all metrics**, indicating strong dependence on hyperparameter selection.
# * **Logistic Regression** exhibited **moderate sensitivity**, with F1-score being most affected by hyperparameter changes.
# * **kNN and Gaussian Naive Bayes** showed **near-zero variance**, demonstrating high robustness to hyperparameter tuning.
# * **F1-score was generally more sensitive than accuracy**, highlighting the impact of class balance on model performance.
# * Low variance indicates **model stability**, but does not necessarily imply superior predictive performance.
# * Models involving **regularization and margin optimization** require more careful tuning than probabilistic or instance-based models.
# * Overall, **model complexity correlates with hyperparameter sensitivity** across classifiers.
